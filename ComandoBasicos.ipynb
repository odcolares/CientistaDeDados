# %%
# importando as bibliotecas
import pandas as pd

# %%
# leitura de planilhas excel
# 2 abas (worksheets)
# leitura do arquivo todo
excel_file = pd.ExcelFile("C:/Users/odair.colares/Documents/AnalistaDeDados/cursosprouni.xls")

# %%
# leitura da primeira aba (Sheet1)
# dados numéricos com separador decimal = '.'
df = pd.read_excel(excel_file, sheet_name='Sheet1').sample(10).T
df
# Out:
#                grau              turno  mensalidade  bolsa_integral_cotas  \
# 14426   Bacharelado           Matutino       626.22                   1.0
# 2216    Bacharelado           Integral      1465.10                   0.0
# 12537   Bacharelado            Noturno       706.55                   3.0
# 16064   Tecnológico           Matutino       563.80                   NaN
# 19750   Bacharelado  Curso a Distância       417.14                   0.0
# 1161    Bacharelado           Integral      1760.00                   2.0
# 39458  Licenciatura  Curso a Distância       230.00                   NaN
# 25211   Tecnológico  Curso a Distância       315.00                   1.0
# 3123    Bacharelado            Noturno      1341.00                   NaN
# 1035    Tecnológico            Noturno      1840.00                   2.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 14426                   2.0                  NaN                  NaN
# 2216                    3.0                  NaN                  NaN
# 12537                   1.0                  NaN                  5.0
# 16064                   NaN                  NaN                 40.0
# 19750                   1.0                  NaN                  NaN
# 1161                   12.0                  NaN                 14.0
# 39458                   NaN                  NaN                  1.0
# 25211                   3.0                  NaN                  NaN
# 3123                    NaN                  NaN                  6.0
# 1035                    1.0                  NaN                  NaN
#
#               curso_id           curso_busca     cidade_busca uf_busca  \
# 14426  105877510699861            Enfermagem          Taubate       SP
# 2216         226209624            Enfermagem     Santo Angelo       RS
# 12537  106572712630883         Administração        Fortaleza       CE
# 16064   10257811213701             Logística         Campinas       SP
# 19750       9191953935    Ciências Contábeis         Campinas       SP
# 1161         592208284  Medicina Veterinária  Pocos de Caldas       MG
# 39458  200596613142345              História      Carapicuiba       SP
# 25211   65788813410085    Serviços Jurídicos         Londrina       PR
# 3123     1046873832083   Ciências Biológicas   Belo Horizonte       MG
# 1035   104321013497043            Radiologia    Montes Claros       MG
#
#           cidade_filtro                                  universidade_nome  \
# 14426  MzUxMzA1MDU0MTAy    Instituto Taubaté de Ensino Superior - I.T.E.S.
# 2216   NDMwMTAwNzE3NTA5  Universidade Regional Integrada do Alto Urugua...
# 12537  MjMwMzAxNjA0NDAw  Faculdade Educacional Fortaleza - Edufor - EDUFOR
# 16064  MzUwNzAzMjA5NTAy                   Faculdade Esamc Campinas - ESAMC
# 19750  MzUwNzAzMjA5NTAy  Centro Universitário Estácio de Ribeirão Preto...
# 1161   MzExMDA1MTUxODAw  Pontifícia Universidade Católica de Minas Gera...
# 39458  MzUxNTA1NzEwNjA5  Centro Universitário Internacional - Uninter -...
# 25211  NDEwMzAxMTEzNzAw  Centro Universitário Filadélfia - Unifil - UNIFIL
# 3123   MzEwNzAzMDA2MjAw                     Centro Universitário Una - UNA
# 1035   MzEwMjAwNzQzMzAy               Instituto de Ciências da Saúde - ICS
#
#                                              campus_nome  campus_id  \
# 14426               AVENIDA DOM PEDRO I - Jardim Eulália    1058775
# 2216              CAMPUS DE SANTO ÂNGELO - Universitário        226
# 12537                 CAMPUS PRINCIPAL - Demócrito Rocha    1065727
# 16064               CAMPUS  - CAMPINAS - CENTRO - Centro     102578
# 19750            EAD CAMPINAS - SP - Jardim Monte Cristo       9191
# 1161   UNIDADE/POLO POÇOS DE CALDAS - Jardim Country ...        592
# 39458                           PAP CARAPICUIBA - Centro    2005966
# 25211               CAMPUS  - LONDRINA - CENTRO - Centro     657888
# 3123                          CAMPUS GUAJAJARAS - Centro    1046873
# 1035                       UNIDADE AMAZONAS - Indústrial    1043210
#
#                        nome  nota_integral_ampla  nota_integral_cotas  \
# 14426            Enfermagem               580.78               561.56
# 2216             Enfermagem               590.22                  NaN
# 12537         Administração               631.06               609.62
# 16064             Logística                  NaN                  NaN
# 19750    Ciências Contábeis               450.00                  NaN
# 1161   Medicina Veterinária               657.60               639.54
# 39458              História                  NaN                  NaN
# 25211    Serviços Jurídicos               551.08               498.52
# 3123    Ciências Biológicas                  NaN                  NaN
# 1035             Radiologia               614.68               605.04
#
#        nota_parcial_ampla  nota_parcial_cotas
# 14426                 NaN                 NaN
# 2216                  NaN                 NaN
# 12537              519.96                 NaN
# 16064              450.00                 NaN
# 19750                 NaN                 NaN
# 1161               605.06                 NaN
# 39458              528.68                 NaN
# 25211                 NaN                 NaN
# 3123               608.30                 NaN
# 1035                  NaN                 NaN

# %%
# Visualizar as N primeiras linhas com metodo df.head(n)
# Visualizar as N ultimas linhas com metodo df.tail(n)
# Visualizar N linhas aleatorias dentro do seu dataset com o metodo df.sample(n)
n = 5
df.head(n)

# %%
# Visualizar tamanho do dataset com numeros de linhas e colunas
df.shape

# %%
# Dtypes saber qual os dados inseridos do dataset
df.dtypes

# %%
# Estatitiscas basicas
df.describe()

# %%
# Infos sobre o dataset
df.info()

# %%
# Nomes das colunas
df.columns

# %%
df['cidade_busca'].value_counts(ascending = True).reset_index()

# %%
df[df['grau'] == 'Tecnológico']

# %%
# Encontrar colunas por parte do nome.
df.filter(like='bo')
