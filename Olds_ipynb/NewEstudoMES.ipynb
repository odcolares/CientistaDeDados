# %%
#Importando as libs
import pandas as pd
import plotly.express as px

# %%
# Carregando DateSet
excel_file = pd.ExcelFile("C:/Users/odair.colares/Documents/1_AnalistaDeDados/mesneww.xlsx")
df = pd.read_excel(excel_file, sheet_name='mes')
df.head()
# Out:
#          Linha     Turno                        Lider                 Data  \
# 0  TT LINHA 04  1º Turno  Dagoberto Guedes dos Santos  04/05/2021 09:35:06
# 1  TT LINHA 05  1º Turno  Dagoberto Guedes dos Santos  04/05/2021 10:50:53
# 2  TT LINHA 07  1º Turno  Dagoberto Guedes dos Santos  04/05/2021 11:01:35
# 3  TT LINHA 03  1º Turno    Eduardo de Castro Marinho  06/05/2021 09:14:36
# 4  TT LINHA 06  1º Turno    Eduardo de Castro Marinho  06/05/2021 09:44:17
#
#    Semana  Mes        Modelo  Horas Disponiveis  Unnamed: 8  \
# 0      19    5  997100150827               8.48         NaN
# 1      19    5  997100150827               8.48         NaN
# 2      19    5  997100150827               8.48         NaN
# 3      19    5  995800010820               8.48         NaN
# 4      19    5  997100150827               8.48         NaN
#
#    Minutos Disponiveis  ... Tempo Parado %  \
# 0                508.8  ...          0,14%
# 1                508.8  ...          0,28%
# ...

# %% [markdown]
# ## Qual a área com mais apontamento de parada?

# %%
df2 = df['Causa'].value_counts().reset_index()
df2.head(10)
#px.bar(df2, x='Causa', y=None, title='Maiores indicadores de paradas')
# Out:
#                                         index  Causa
# 0                  115 - AJUSTE DE ENGENHARIA     75
# 1                 126 - ANALISE DA ENGENHARIA     38
# 2  91 - AGUARDANDO CONCLUSÃO HORAS DE BURN-IN     20
# 3                       148 - FALTA DE PLACAS     14
# 4    74 - ATUALIZAÇÃO FIRMWARE ROTEADOR WI-FI      8
# 5             47 - COLABORADOR EM TREINAMENTO      8
# 6                  125 - AJUSTE DA MANUTENÇÃO      6
# 7                  100 - INTEGRAÇÃO DE PLACAS      5
# 8            135 - ATUALIZAÇÃO DO SISTEMA MES      5
# 9          85 - FALHA NA REIMPRESÃO DO SERIAL      5

# %% [markdown]
# ## Modelo com maior numero de parada.

# %%
df3 = df['Modelo'].value_counts().reset_index()
df3.head()
# Out:
#              index  Modelo
# 0  70420000AAA0002     121
# 1  7043000000A0005      63
# 2     997100250825      41
# 3     997100240826      41
# 4  7043000000A0004      28
